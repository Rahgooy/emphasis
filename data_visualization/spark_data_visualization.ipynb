# %% [markdown]
# # Pie chart for occurrence of POS's

# %%
import sys
sys.path.append('../')
import Read_data_and_Write_results as rw
import matplotlib.pyplot as plt
import visualization_helper as vh

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size

# %%
pos_lsts = rw.read_data("datasets/s-train.txt")[5]
pos_lsts = [item for innerlist in pos_lsts for item in innerlist]

# %%
pos_dict = { "J": 0, "V": 0,"CD": 0, "N": 0, "R": 0, "Other": 0}
pos_counter = vh.pos_counter(pos_lsts, pos_dict)

# %%
pos_counter
# Out:
# {'J': 322, 'V': 614, 'CD': 212, 'N': 2189, 'R': 139, 'Other': 1659}

# %%
vh.pie_fig(pos_counter, (0, 0, 0, 0.1, 0, 0))

# %% [markdown]
# # Scatter for occerrence and probability of words
# ---

# %%
_,word_vocab,_,_,word_probs ,_ = rw.read_data("../datasets/s-train.txt")

# %%
bold_occurrences_word = vh.get_bold_occurrences_word(word_vocab, word_probs)
occurrences_word = vh.get_occurrences_word(word_vocab)
print(len(occurrences_word))
# Out:
# 1652

# %%
uniqe_counter = 0
for word in occurrences_word:
    if occurrences_word[word] == 1:
        uniqe_counter += 1
print(uniqe_counter)
print(len(occurrences_word))
# Out:
# 1033
# 1652

# %%
probs, freqs, words = vh.calculate_freqs_probs(bold_occurrences_word,occurrences_word, 0, 0)
print(len(words))
vh.scatter_plot(freqs,probs, words, "Frequency", "Probability")
# Out:
# 588

# %% [markdown]
# # Scatter for occurrenece and bold_freq of words

# %%
_, word_lsts, _, bio_freqs, _, _  = rw.read_data("../datasets/s-train.txt")

# %%
bio_freqs_word = vh.get_bio_freqs_word(bio_freqs, word_lsts)
occurrenece_word = vh.get_occurrences_word(word_lsts)
bios_probs, words_freq, words = vh.calculate_bio_probs(bio_freqs_word, occurrenece_word, [9, 54], [1, 6])
print(len(words_freq))
# Out:
# 274

# %%
vh.scatter_plot(words_freq, bios_probs, words, "Freqency", "Bio Probability")

# %% [markdown]
# # Scatter for occurrenece and bold_freq of POS

# %%
_, _, _, bio_freqs, _, pos_lsts  = rw.read_data("datasets/s-train.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-103-4f9eb20b3f70> in <module>
# ----> 1 _, _, _, bio_freqs, _, pos_lsts  = rw.read_data("datasets/s-train.txt")
#
# D:\Emphasis_Selection\Main\Expreiments\Read_data_and_Write_results.py in read_data(filename)
#       6     :return: lists of word_ids, words, emphasis probabilities, POS tags
#       7     """
# ----> 8     lines = read_lines(filename) + ['']
#       9     word_id_lst, word_id_lsts =[], []
#      10     post_lst, post_lsts = [], []
#
# D:\Emphasis_Selection\Main\Expreiments\Read_data_and_Write_results.py in read_lines(filename)
#      47
#      48 def read_lines( filename):
# ---> 49     with open(filename, 'r') as fp:
#      50         lines = [line.strip() for line in fp]
#      51     return lines
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/s-train.txt'

# %%
bio_freqs_pos, occurrenece_pos = vh.get_bio_freqs_pos(bio_freqs, pos_lsts)
bios_probs, pos_freq, pos = vh.calculate_bio_probs(bio_freqs_pos, occurrenece_pos, [0, 1000000000], [0, 10000])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-28675373aa7a> in <module>
# ----> 1 bio_freqs_pos, occurrenece_pos = vh.get_bio_freqs_pos(bio_freqs, pos_lsts)
#       2 bios_probs, pos_freq, pos = vh.calculate_bio_probs(bio_freqs_pos, occurrenece_pos, [0, 1000000000], [0, 10000])
#
# NameError: name 'pos_lsts' is not defined

# %%
print(pos_freq)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-aca63ae8dcfe> in <module>
# ----> 1 print(pos_freq)
#
# NameError: name 'pos_freq' is not defined

# %%
vh.scatter_plot(pos_freq, bios_probs, pos, "POS Frequency", "Bio Probability", xlim = False)
